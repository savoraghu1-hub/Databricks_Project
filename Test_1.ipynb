# %% [markdown]
# Welcome

# %%
print("Welcome to the Databricks")

# %%
# %sql
select * from workspace.default.employees

# %%
a = 10
b = 5
print(f"First: {a, b}")

"""
First: (10, 5)
"""

a, b = b, a + 2
print(f"Second: {a, b}")

"""
Second: (5, 12)
"""

# %%
print("hello")
